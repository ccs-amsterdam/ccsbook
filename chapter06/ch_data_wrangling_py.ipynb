# %%
# !pip3 install pandas scipy seaborn xlrd
# Out:
# Requirement already satisfied: pandas in /home/wva/ccsbook/env/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: scipy in /home/wva/ccsbook/env/lib/python3.8/site-packages (1.7.0)
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 21.7 MB/s eta 0:00:01
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 8.6 MB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/wva/ccsbook/env/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/wva/ccsbook/env/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/wva/ccsbook/env/lib/python3.8/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in /home/wva/ccsbook/env/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 40.4 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 116.9 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/wva/ccsbook/env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 106.8 MB/s eta 0:00:01
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib, xlrd, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.3.0 seaborn-0.11.1 xlrd-2.0.1

# %%
import pandas as pd
import seaborn as sns
import scipy.stats
import re

# %%
url="https://cssbook.net/d/guns-polls.csv"
d=pd.read_csv(url)
d = d.rename(columns={"Republican Support": "rep",
    "Democratic Support": "dem"})
d = d.drop(columns="URL")   
# alternatively, we can write:
# d.drop(columns="URL", inplace=True)   
d2 = d.loc[d.Question == "arm-teachers"]
d2
# Out:
#         Question    Start      End         Pollster         Population  \
# 7   arm-teachers  2/23/18  2/25/18  YouGov/Huffpost  Registered Voters
# 8   arm-teachers  2/20/18  2/23/18         CBS News             Adults
# 9   arm-teachers  2/27/18  2/28/18        Rasmussen             Adults
# 10  arm-teachers  2/27/18  2/28/18        NPR/Ipsos             Adults
# 11  arm-teachers   3/3/18   3/5/18       Quinnipiac  Registered Voters
# 12  arm-teachers  2/26/18  2/28/18     SurveyMonkey  Registered Voters
#
#     Support  rep  dem
# 7        41   69   20
# 8        44   68   20
# 9        43   71   24
# 10       41   68   18
# 11       40   77   10
# 12       43   80   11

# %%
# version of the guns polls with some errors 
url="https://cssbook.net/d/guns-polls-dirty.csv"
d2=pd.read_csv(url)

# Option 1: clean with direct assignment
# Note that when creating a new column, 
# you have to use df["col"] rather than df.col 
d2["rep2"] = d2.rep.str.replace("[^0-9\\.]", "")
d2["rep2"] = pd.to_numeric(d2.rep2)
d2["Support2"]=d2.Support.fillna(d.Support.mean())

# Alternatively, clean with apply 
# Note the need to use an anonymous function
# (lambda) to chain calculations
cleaned = d2.assign(
    rep2 = d2.rep.str.replace("[^0-9\\.]", ""),
    rep3 = lambda d2: pd.to_numeric(d2.rep2),
    Support2=d2.Support.fillna(d2.Support.mean()))

# Finally, you can create your own function 
def clean_num(x):
    x = re.sub("[^0-9\\.]", "", x)
    return int(x)

cleaned["rep3"] = cleaned.rep.apply(clean_num)
cleaned.head()
# Out:
# /tmp/ipykernel_9930/3539114726.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   d2["rep2"] = d2.rep.str.replace("[^0-9\\.]", "")
# /tmp/ipykernel_9930/3539114726.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   rep2 = d2.rep.str.replace("[^0-9\\.]", ""),
#        Question    Start      End         Pollster         Population  \
# 0  arm-teachers  2/23/18  2/25/18  YouGov/Huffpost  Registered Voters
# 1  arm-teachers  2/20/18  2/23/18         CBS News             Adults
# 2  arm-teachers  2/27/18  2/28/18        Rasmussen             Adults
# 3  arm-teachers  2/27/18  2/28/18        NPR/Ipsos             Adults
# 4  arm-teachers   3/3/18   3/5/18       Quinnipiac  Registered Voters
#
#    Support  rep  dem rep2  Support2  rep3
# 0     41.0   69   20   69      41.0    69
# 1      NaN   68   20   68      41.6    68
# 2     43.0  71d   24   71      43.0    71
# 3     41.0   68   18   68      41.0    68
# 4     40.0   77   10   77      40.0    77

# %%
groups = d.groupby("Question")
groups.agg({"Support": ["mean", "std"]})
# Out:
#                                Support
#                                   mean       std
# Question
# age-21                       75.857143  6.011893
# arm-teachers                 42.000000  1.549193
# background-checks            87.428571  7.322503
# ban-assault-weapons          61.750000  6.440285
# ban-high-capacity-magazines  67.285714  3.860669
# mental-health-own-gun        85.833333  5.455884
# repeal-2nd-amendment         10.000000       NaN
# stricter-gun-laws            66.454545  5.145165

# %%
d.groupby("Question").agg(
    {"Support": ["mean", "std"]})
# Out:
#                                Support
#                                   mean       std
# Question
# age-21                       75.857143  6.011893
# arm-teachers                 42.000000  1.549193
# background-checks            87.428571  7.322503
# ban-assault-weapons          61.750000  6.440285
# ban-high-capacity-magazines  67.285714  3.860669
# mental-health-own-gun        85.833333  5.455884
# repeal-2nd-amendment         10.000000       NaN
# stricter-gun-laws            66.454545  5.145165

# %%
# Note the use of ( ) to split a long line
d["mean"] = (d.groupby("Question")["Support"]
              .transform("mean"))
d["deviation"] = d["Support"] - d["mean"]
d.head()
# Out:
#   Question    Start      End            Pollster         Population  Support  \
# 0   age-21  2/20/18  2/23/18            CNN/SSRS  Registered Voters       72
# 1   age-21  2/27/18  2/28/18           NPR/Ipsos             Adults       82
# 2   age-21   3/1/18   3/4/18           Rasmussen             Adults       67
# 3   age-21  2/22/18  2/26/18  Harris Interactive  Registered Voters       84
# 4   age-21   3/3/18   3/5/18          Quinnipiac  Registered Voters       78
#
#    rep  dem       mean  deviation
# 0   61   86  75.857143  -3.857143
# 1   72   92  75.857143   6.142857
# 2   59   76  75.857143  -8.857143
# 3   77   92  75.857143   8.142857
# 4   63   93  75.857143   2.142857
